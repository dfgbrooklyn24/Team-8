# %%
import pandas as pd
import numpy as np

schools_data = pd.read_csv('../shared_data_read_only/Education-Data/2023-2024 Master School List (20231003).csv')
schools_data.head()

enroll_data = pd.read_csv('../shared_data_read_only/Education-Data/2023-2024 Enrollment & Demographics.csv')

mat_data = pd.read_csv('../shared_data_read_only/Education-Data/SDP_College_Matriculation_2021-2022.csv')

grad_data = pd.read_csv('../shared_data_read_only/Education-Data/SDP_Graduation_Rates_School_S_2023-02-15.csv')

attendance_data = pd.read_csv('../shared_data_read_only/Education-Data/Student_ADA_Yearly.csv')
attendance_data.head()
# Out:
#   School Year    Sector  ULCS Code  \
# 0   2022-2023  District       1010
# 1   2022-2023  District       1020
# 2   2022-2023  District       1030
# 3   2022-2023  District       1050
# 4   2022-2023  District       1100
#
#                                    School Name  Average Daily Attendance (YTD)
# 0                     John Bartram High School                           77.27
# 1                West Philadelphia High School                           80.34
# 2                    High School of the Future                           84.49
# 3  Paul Robeson High School for Human Services                           91.50
# 4                 William L. Sayre High School                           82.52

# %%
final_zips = [19132, 19121, 19134, 19133, 19124]

new_df = pd.DataFrame()

for zips in final_zips:
    zip_df = schools_data.loc[schools_data['Zip Code'] == zips]
    zip_df = zip_df.loc[zip_df['Grade 9'] == 1]

    zip_schools = zip_df['ULCS Code'].to_numpy()
    
    enroll_data_t = enroll_data.loc[enroll_data['ulcscode'].isin(zip_schools)]
    enroll_data_t = enroll_data_t.loc[enroll_data_t['GradeLevel'].str.contains('All Grades')]
    
    enroll_data_t = enroll_data_t[["Sector", 'ulcscode', "SchoolName", "StudentEnrollment", "BlackAfricanAmericanPCT", "CEPEconomicallyDisadvantagedRate"]]

    enroll_data_t.loc[len(enroll_data_t.index)] = ['N/A', 'N/A', 'Average', enroll_data_t['StudentEnrollment'].mean(), enroll_data_t['BlackAfricanAmericanPCT'].mean(), enroll_data_t['CEPEconomicallyDisadvantagedRate'].mean()]
    enroll_data_t.loc[len(enroll_data_t.index)] = ['N/A', 'N/A', 'Median', enroll_data_t['StudentEnrollment'].median(), enroll_data_t['BlackAfricanAmericanPCT'].median(), enroll_data_t['CEPEconomicallyDisadvantagedRate'].median()]
    enroll_data_t.insert(1, "Zip Code", [zips] * len(enroll_data_t), True)
    
    enroll_data_t.round(2)
    new_df = pd.concat([new_df, enroll_data_t], ignore_index=True)

display(new_df)
# Out:
#          Sector  Zip Code ulcscode  \
# 0       Charter     19132     3441
# 1      District     19132     4060
# 2   Alternative     19132     8450
# 3           N/A     19132      N/A
# 4           N/A     19132      N/A
# 5   Alternative     19121     2310
# 6   Alternative     19121     3510
# 7      District     19121     4030
# 8      District     19121     4140
# 9      District     19121     5180
# 10  Alternative     19121     8080
# 11  Alternative     19121     8860
# 12  Alternative     19121     8870
# 13          N/A     19121      N/A
# 14          N/A     19121      N/A
# 15     District     19134     5060
# 16          N/A     19134      N/A
# 17          N/A     19134      N/A
# 18  Alternative     19133     8190
# 19          N/A     19133      N/A
# 20          N/A     19133      N/A
# 21  Alternative     19124     3290
# 22      Charter     19124     3301
# 23      Charter     19124     3332
# 24      Charter     19124     3364
# 25     District     19124     7010
# 26     District     19124     7120
# 27  Alternative     19124     8890
# 28  Alternative     19124     8891
# 29          N/A     19124      N/A
# 30          N/A     19124      N/A
#
#                                            SchoolName  StudentEnrollment  \
# 0                          TECH Freire Charter School         494.000000
# 1    Murrell Dobbins Career and Technical High School         774.000000
# 2                                           YESPhilly         126.000000
# 3                                             Average         464.666667
# 4                                              Median         479.333333
# 5                                     Achieve Academy          50.000000
# 6              El Centro de Estudiantes (Big Picture)         100.000000
# 7              High School of Engineering and Science         843.000000
# 8                      Strawberry Mansion High School         249.000000
# 9                     Vaux High School: A Big Picture         305.000000
# 10                                Excel Academy North         208.000000
# 11                             One Bright Ray Mansion         105.000000
# 12                     One Bright Ray Mansion Evening          79.000000
# 13                                            Average         242.375000
# 14                                             Median         208.000000
# 15  Jules E. Mastbaum Area Vocational Technical Hi...         591.000000
# 16                                            Average         591.000000
# 17                                             Median         591.000000
# 18                   One Bright Ray - Fairhill Campus         261.000000
# 19                                            Average         261.000000
# 20                                             Median         261.000000
# 21                                Excel Academy South         207.000000
# 22   Community Academy of Philadelphia Charter School        1246.000000
# 23            Mariana Bracetti Academy Charter School        1509.000000
# 24      First Philadelphia Preparatory Charter School        1857.000000
# 25                              Frankford High School         861.000000
# 26                            Samuel Fels High School        1238.000000
# 27                    One Bright Ray - Simpson Campus         267.000000
# 28                   One Bright Ray Simpson - Evening         131.000000
# 29                                            Average         914.500000
# 30                                             Median         914.500000
#
#     BlackAfricanAmericanPCT  CEPEconomicallyDisadvantagedRate
# 0                   93.5200                               NaN
# 1                   89.4100                           100.000
# 2                   91.2700                           100.000
# 3                   91.4000                           100.000
# 4                   91.3350                           100.000
# 5                   92.0000                           100.000
# 6                   52.0000                             1.600
# 7                   58.9600                            92.430
# 8                   92.3700                           100.000
# 9                   89.5100                             1.050
# 10                  91.8300                           100.000
# 11                  87.6200                           100.000
# 12                  88.6100                             0.000
# 13                  81.6125                            61.885
# 14                  88.6100                            92.430
# 15                  43.1500                           100.000
# 16                  43.1500                           100.000
# 17                  43.1500                           100.000
# 18                  41.3800                             0.610
# 19                  41.3800                             0.610
# 20                  41.3800                             0.610
# 21                  48.3100                           100.000
# 22                   9.9500                               NaN
# 23                  21.1400                               NaN
# 24                  47.2300                               NaN
# 25                  40.3000                           100.000
# 26                  38.3700                           100.000
# 27                  38.2000                             0.000
# 28                  40.4600                             0.000
# 29                  35.4950                            60.000
# 30                  38.3700                            80.000

# %%
new_df.insert(6, 'Matriculation Rate', [np.NaN] * len(new_df))

for i in range(len(new_df)):
    school = new_df.iloc[i, 2]
    if school == 'N/A': continue
    mat_df = mat_data.loc[mat_data['ULCS Code'] == school]
    if mat_df.empty: continue
    new_df.at[i, 'Matriculation Rate'] = mat_df.iloc[0, 4]
    
display(new_df)
# Out:
#          Sector  Zip Code ulcscode  \
# 0       Charter     19132     3441
# 1      District     19132     4060
# 2   Alternative     19132     8450
# 3           N/A     19132      N/A
# 4           N/A     19132      N/A
# 5   Alternative     19121     2310
# 6   Alternative     19121     3510
# 7      District     19121     4030
# 8      District     19121     4140
# 9      District     19121     5180
# 10  Alternative     19121     8080
# 11  Alternative     19121     8860
# 12  Alternative     19121     8870
# 13          N/A     19121      N/A
# 14          N/A     19121      N/A
# 15     District     19134     5060
# 16          N/A     19134      N/A
# 17          N/A     19134      N/A
# 18  Alternative     19133     8190
# 19          N/A     19133      N/A
# 20          N/A     19133      N/A
# 21  Alternative     19124     3290
# 22      Charter     19124     3301
# 23      Charter     19124     3332
# 24      Charter     19124     3364
# 25     District     19124     7010
# 26     District     19124     7120
# 27  Alternative     19124     8890
# 28  Alternative     19124     8891
# 29          N/A     19124      N/A
# 30          N/A     19124      N/A
#
#                                            SchoolName  StudentEnrollment  \
# 0                          TECH Freire Charter School         494.000000
# 1    Murrell Dobbins Career and Technical High School         774.000000
# 2                                           YESPhilly         126.000000
# 3                                             Average         464.666667
# 4                                              Median         479.333333
# 5                                     Achieve Academy          50.000000
# 6              El Centro de Estudiantes (Big Picture)         100.000000
# 7              High School of Engineering and Science         843.000000
# 8                      Strawberry Mansion High School         249.000000
# 9                     Vaux High School: A Big Picture         305.000000
# 10                                Excel Academy North         208.000000
# 11                             One Bright Ray Mansion         105.000000
# 12                     One Bright Ray Mansion Evening          79.000000
# 13                                            Average         242.375000
# 14                                             Median         208.000000
# 15  Jules E. Mastbaum Area Vocational Technical Hi...         591.000000
# 16                                            Average         591.000000
# 17                                             Median         591.000000
# 18                   One Bright Ray - Fairhill Campus         261.000000
# 19                                            Average         261.000000
# 20                                             Median         261.000000
# 21                                Excel Academy South         207.000000
# 22   Community Academy of Philadelphia Charter School        1246.000000
# 23            Mariana Bracetti Academy Charter School        1509.000000
# 24      First Philadelphia Preparatory Charter School        1857.000000
# 25                              Frankford High School         861.000000
# 26                            Samuel Fels High School        1238.000000
# 27                    One Bright Ray - Simpson Campus         267.000000
# 28                   One Bright Ray Simpson - Evening         131.000000
# 29                                            Average         914.500000
# 30                                             Median         914.500000
#
#     BlackAfricanAmericanPCT  Matriculation Rate  \
# 0                   93.5200                 NaN
# 1                   89.4100               25.95
# 2                   91.2700                 NaN
# 3                   91.4000                 NaN
# 4                   91.3350                 NaN
# 5                   92.0000                 NaN
# 6                   52.0000                 NaN
# 7                   58.9600               78.79
# 8                   92.3700                0.00
# 9                   89.5100               36.17
# 10                  91.8300                 NaN
# 11                  87.6200                 NaN
# 12                  88.6100                 NaN
# 13                  81.6125                 NaN
# 14                  88.6100                 NaN
# 15                  43.1500               20.25
# 16                  43.1500                 NaN
# 17                  43.1500                 NaN
# 18                  41.3800                 NaN
# 19                  41.3800                 NaN
# 20                  41.3800                 NaN
# 21                  48.3100                 NaN
# 22                   9.9500                 NaN
# 23                  21.1400                 NaN
# 24                  47.2300                 NaN
# 25                  40.3000               21.85
# 26                  38.3700               27.71
# 27                  38.2000                 NaN
# 28                  40.4600                 NaN
# 29                  35.4950                 NaN
# 30                  38.3700                 NaN
#
#     CEPEconomicallyDisadvantagedRate
# 0                                NaN
# 1                            100.000
# 2                            100.000
# 3                            100.000
# 4                            100.000
# 5                            100.000
# 6                              1.600
# 7                             92.430
# 8                            100.000
# 9                              1.050
# 10                           100.000
# 11                           100.000
# 12                             0.000
# 13                            61.885
# 14                            92.430
# 15                           100.000
# 16                           100.000
# 17                           100.000
# 18                             0.610
# 19                             0.610
# 20                             0.610
# 21                           100.000
# 22                               NaN
# 23                               NaN
# 24                               NaN
# 25                           100.000
# 26                           100.000
# 27                             0.000
# 28                             0.000
# 29                            60.000
# 30                            80.000

# %%
final_schools = []

for i in range(len(new_df)):
    school = new_df.iloc[i, 2]
    if school == 'N/A': continue
    final_schools.append(school)

grad_df = grad_data.loc[grad_data['schoolid_ulcs'].isin(final_schools)]
grad_df = grad_df.loc[grad_df['rate_type'] == '4-Year Graduation Rate']
focus_rows = ['All Students', 'Economically Disadvantaged', 'Black/African American']
grad_df = grad_df.loc[grad_df['subgroup'].isin(focus_rows)]

grad_df
# Out:
#           cohort  schoolid_ulcs                        schoolname  \
# 603    2010-2011           2310                   Achieve Academy
# 604    2010-2011           2310                   Achieve Academy
# 609    2010-2011           2310                   Achieve Academy
# 1052   2010-2011           3290               Excel Academy South
# 1053   2010-2011           3290               Excel Academy South
# ...          ...            ...                               ...
# 26141  2018-2019           8890   One Bright Ray - Simpson Campus
# 26145  2018-2019           8890   One Bright Ray - Simpson Campus
# 26152  2018-2019           8891  One Bright Ray Simpson - Evening
# 26153  2018-2019           8891  One Bright Ray Simpson - Evening
# 26156  2018-2019           8891  One Bright Ray Simpson - Evening
#
#             sector               rate_type                       group  \
# 603    Alternative  4-Year Graduation Rate                All Students
# 604    Alternative  4-Year Graduation Rate  Economically Disadvantaged
# 609    Alternative  4-Year Graduation Rate                   Ethnicity
# 1052   Alternative  4-Year Graduation Rate                All Students
# 1053   Alternative  4-Year Graduation Rate  Economically Disadvantaged
# ...            ...                     ...                         ...
# 26141  Alternative  4-Year Graduation Rate  Economically Disadvantaged
# 26145  Alternative  4-Year Graduation Rate                   Ethnicity
# 26152  Alternative  4-Year Graduation Rate                All Students
# 26153  Alternative  4-Year Graduation Rate  Economically Disadvantaged
# 26156  Alternative  4-Year Graduation Rate                   Ethnicity
#
#                          subgroup  denom  num  score
# 603                  All Students     73   28  38.36
# 604    Economically Disadvantaged     52   22  42.31
# 609        Black/African American     65   26     40
# 1052                 All Students    303  154  50.83
# 1053   Economically Disadvantaged    228  112  49.12
# ...                           ...    ...  ...    ...
# 26141  Economically Disadvantaged     44    4   9.09
# 26145      Black/African American     35    s      s
# 26152                All Students     21    s      s
# 26153  Economically Disadvantaged     16    s      s
# 26156      Black/African American     10    s      s
#
# [390 rows x 10 columns]

# %%
# new_df.insert(8, 'Grad Rate', [np.NaN] * len(new_df))
# new_df.insert(9, 'Grad Rate for Economically Disadvantaged Students', [np.NaN] * len(new_df))
# new_df.insert(10, 'Grad Rate for Black/African American Students', [np.NaN] * len(new_df))

for school in final_schools:
    temp_df = grad_df.loc[grad_df['schoolid_ulcs'] == school]
    
    all_df = temp_df.loc[temp_df['subgroup'] == 'All Students']
    all_df = all_df[all_df['score'] != 's']
    all_df['score'] = all_df['score'].astype(float)
    
    econ_df = temp_df.loc[temp_df['subgroup'] == 'Economically Disadvantaged']
    econ_df = econ_df[econ_df['score'] != 's']
    econ_df['score'] = econ_df['score'].astype(float)
    
    eth_df = temp_df.loc[temp_df['subgroup'] == 'Black/African American']
    eth_df = eth_df[eth_df['score'] != 's']
    eth_df['score'] = eth_df['score'].astype(float)
    
    row_index = new_df.index.get_loc(new_df[new_df['ulcscode'] == school].index[0])
    new_df.at[row_index, 'Grad Rate'] = all_df['score'].mean()
    new_df.at[row_index, 'Grad Rate for Economically Disadvantaged Students'] = econ_df['score'].mean()
    new_df.at[row_index, 'Grad Rate for Black/African American Students'] = eth_df['score'].mean()
    
display(new_df)
# Out:
#          Sector  Zip Code ulcscode  \
# 0       Charter     19132     3441
# 1      District     19132     4060
# 2   Alternative     19132     8450
# 3           N/A     19132      N/A
# 4           N/A     19132      N/A
# 5   Alternative     19121     2310
# 6   Alternative     19121     3510
# 7      District     19121     4030
# 8      District     19121     4140
# 9      District     19121     5180
# 10  Alternative     19121     8080
# 11  Alternative     19121     8860
# 12  Alternative     19121     8870
# 13          N/A     19121      N/A
# 14          N/A     19121      N/A
# 15     District     19134     5060
# 16          N/A     19134      N/A
# 17          N/A     19134      N/A
# 18  Alternative     19133     8190
# 19          N/A     19133      N/A
# 20          N/A     19133      N/A
# 21  Alternative     19124     3290
# 22      Charter     19124     3301
# 23      Charter     19124     3332
# 24      Charter     19124     3364
# 25     District     19124     7010
# 26     District     19124     7120
# 27  Alternative     19124     8890
# 28  Alternative     19124     8891
# 29          N/A     19124      N/A
# 30          N/A     19124      N/A
#
#                                            SchoolName  StudentEnrollment  \
# 0                          TECH Freire Charter School         494.000000
# 1    Murrell Dobbins Career and Technical High School         774.000000
# 2                                           YESPhilly         126.000000
# 3                                             Average         464.666667
# 4                                              Median         479.333333
# 5                                     Achieve Academy          50.000000
# 6              El Centro de Estudiantes (Big Picture)         100.000000
# 7              High School of Engineering and Science         843.000000
# 8                      Strawberry Mansion High School         249.000000
# 9                     Vaux High School: A Big Picture         305.000000
# 10                                Excel Academy North         208.000000
# 11                             One Bright Ray Mansion         105.000000
# 12                     One Bright Ray Mansion Evening          79.000000
# 13                                            Average         242.375000
# 14                                             Median         208.000000
# 15  Jules E. Mastbaum Area Vocational Technical Hi...         591.000000
# 16                                            Average         591.000000
# 17                                             Median         591.000000
# 18                   One Bright Ray - Fairhill Campus         261.000000
# 19                                            Average         261.000000
# 20                                             Median         261.000000
# 21                                Excel Academy South         207.000000
# 22   Community Academy of Philadelphia Charter School        1246.000000
# 23            Mariana Bracetti Academy Charter School        1509.000000
# 24      First Philadelphia Preparatory Charter School        1857.000000
# 25                              Frankford High School         861.000000
# 26                            Samuel Fels High School        1238.000000
# 27                    One Bright Ray - Simpson Campus         267.000000
# 28                   One Bright Ray Simpson - Evening         131.000000
# 29                                            Average         914.500000
# 30                                             Median         914.500000
#
#     BlackAfricanAmericanPCT  Matriculation Rate  \
# 0                   93.5200                 NaN
# 1                   89.4100               25.95
# 2                   91.2700                 NaN
# 3                   91.4000                 NaN
# 4                   91.3350                 NaN
# 5                   92.0000                 NaN
# 6                   52.0000                 NaN
# 7                   58.9600               78.79
# 8                   92.3700                0.00
# 9                   89.5100               36.17
# 10                  91.8300                 NaN
# 11                  87.6200                 NaN
# 12                  88.6100                 NaN
# 13                  81.6125                 NaN
# 14                  88.6100                 NaN
# 15                  43.1500               20.25
# 16                  43.1500                 NaN
# 17                  43.1500                 NaN
# 18                  41.3800                 NaN
# 19                  41.3800                 NaN
# 20                  41.3800                 NaN
# 21                  48.3100                 NaN
# 22                   9.9500                 NaN
# 23                  21.1400                 NaN
# 24                  47.2300                 NaN
# 25                  40.3000               21.85
# 26                  38.3700               27.71
# 27                  38.2000                 NaN
# 28                  40.4600                 NaN
# 29                  35.4950                 NaN
# 30                  38.3700                 NaN
#
#     CEPEconomicallyDisadvantagedRate  Grad Rate  \
# 0                                NaN        NaN
# 1                            100.000  86.692222
# 2                            100.000  20.732500
# 3                            100.000        NaN
# 4                            100.000        NaN
# 5                            100.000  44.345714
# 6                              1.600  21.747778
# 7                             92.430  97.477778
# 8                            100.000  45.828750
# 9                              1.050  85.250000
# 10                           100.000  36.064444
# 11                           100.000  15.252500
# 12                             0.000  40.100000
# 13                            61.885        NaN
# 14                            92.430        NaN
# 15                           100.000  83.617778
# 16                           100.000        NaN
# 17                           100.000        NaN
# 18                             0.610  36.971111
# 19                             0.610        NaN
# 20                             0.610        NaN
# 21                           100.000  37.110000
# 22                               NaN        NaN
# 23                               NaN        NaN
# 24                               NaN        NaN
# 25                           100.000  56.646667
# 26                           100.000  69.825556
# 27                             0.000  20.357143
# 28                             0.000        NaN
# 29                            60.000        NaN
# 30                            80.000        NaN
#
#     Grad Rate for Economically Disadvantaged Students  \
# 0                                                 NaN
# 1                                           87.472857
# 2                                           24.917500
# 3                                                 NaN
# 4                                                 NaN
# 5                                           40.760000
# 6                                           22.478889
# 7                                           97.155556
# 8                                           40.313333
# 9                                                 NaN
# 10                                          40.905714
# 11                                          15.090000
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                          83.396250
# 16                                                NaN
# 17                                                NaN
# 18                                          33.393333
# 19                                                NaN
# 20                                                NaN
# 21                                          36.426667
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                          57.101111
# 26                                          68.932222
# 27                                          20.561667
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#     Grad Rate for Black/African American Students
# 0                                             NaN
# 1                                       87.490000
# 2                                       23.331429
# 3                                             NaN
# 4                                             NaN
# 5                                       48.415000
# 6                                       21.942500
# 7                                       98.055556
# 8                                       43.672000
# 9                                       85.650000
# 10                                      40.568571
# 11                                      14.327500
# 12                                      38.162500
# 13                                            NaN
# 14                                            NaN
# 15                                      86.307778
# 16                                            NaN
# 17                                            NaN
# 18                                      37.277500
# 19                                            NaN
# 20                                            NaN
# 21                                      38.794444
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                      59.858889
# 26                                      73.937778
# 27                                      26.320000
# 28                                            NaN
# 29                                            NaN
# 30                                            NaN

# %%
attendance_df = attendance_data.loc[attendance_data['ULCS Code'].isin(final_schools)]
# new_df.insert(11, 'Attendance Rate', [np.NaN] * len(new_df))

for school in final_schools:
    temp_df = attendance_data.loc[attendance_data['ULCS Code'] == school]
    row_index = new_df.index.get_loc(new_df[new_df['ulcscode'] == school].index[0])
    new_df.at[row_index, 'Attendance Rate'] = temp_df['Average Daily Attendance (YTD)'].mean()
    
display(new_df)
# Out:
#          Sector  Zip Code ulcscode  \
# 0       Charter     19132     3441
# 1      District     19132     4060
# 2   Alternative     19132     8450
# 3           N/A     19132      N/A
# 4           N/A     19132      N/A
# 5   Alternative     19121     2310
# 6   Alternative     19121     3510
# 7      District     19121     4030
# 8      District     19121     4140
# 9      District     19121     5180
# 10  Alternative     19121     8080
# 11  Alternative     19121     8860
# 12  Alternative     19121     8870
# 13          N/A     19121      N/A
# 14          N/A     19121      N/A
# 15     District     19134     5060
# 16          N/A     19134      N/A
# 17          N/A     19134      N/A
# 18  Alternative     19133     8190
# 19          N/A     19133      N/A
# 20          N/A     19133      N/A
# 21  Alternative     19124     3290
# 22      Charter     19124     3301
# 23      Charter     19124     3332
# 24      Charter     19124     3364
# 25     District     19124     7010
# 26     District     19124     7120
# 27  Alternative     19124     8890
# 28  Alternative     19124     8891
# 29          N/A     19124      N/A
# 30          N/A     19124      N/A
#
#                                            SchoolName  StudentEnrollment  \
# 0                          TECH Freire Charter School         494.000000
# 1    Murrell Dobbins Career and Technical High School         774.000000
# 2                                           YESPhilly         126.000000
# 3                                             Average         464.666667
# 4                                              Median         479.333333
# 5                                     Achieve Academy          50.000000
# 6              El Centro de Estudiantes (Big Picture)         100.000000
# 7              High School of Engineering and Science         843.000000
# 8                      Strawberry Mansion High School         249.000000
# 9                     Vaux High School: A Big Picture         305.000000
# 10                                Excel Academy North         208.000000
# 11                             One Bright Ray Mansion         105.000000
# 12                     One Bright Ray Mansion Evening          79.000000
# 13                                            Average         242.375000
# 14                                             Median         208.000000
# 15  Jules E. Mastbaum Area Vocational Technical Hi...         591.000000
# 16                                            Average         591.000000
# 17                                             Median         591.000000
# 18                   One Bright Ray - Fairhill Campus         261.000000
# 19                                            Average         261.000000
# 20                                             Median         261.000000
# 21                                Excel Academy South         207.000000
# 22   Community Academy of Philadelphia Charter School        1246.000000
# 23            Mariana Bracetti Academy Charter School        1509.000000
# 24      First Philadelphia Preparatory Charter School        1857.000000
# 25                              Frankford High School         861.000000
# 26                            Samuel Fels High School        1238.000000
# 27                    One Bright Ray - Simpson Campus         267.000000
# 28                   One Bright Ray Simpson - Evening         131.000000
# 29                                            Average         914.500000
# 30                                             Median         914.500000
#
#     BlackAfricanAmericanPCT  Matriculation Rate  \
# 0                   93.5200                 NaN
# 1                   89.4100               25.95
# 2                   91.2700                 NaN
# 3                   91.4000                 NaN
# 4                   91.3350                 NaN
# 5                   92.0000                 NaN
# 6                   52.0000                 NaN
# 7                   58.9600               78.79
# 8                   92.3700                0.00
# 9                   89.5100               36.17
# 10                  91.8300                 NaN
# 11                  87.6200                 NaN
# 12                  88.6100                 NaN
# 13                  81.6125                 NaN
# 14                  88.6100                 NaN
# 15                  43.1500               20.25
# 16                  43.1500                 NaN
# 17                  43.1500                 NaN
# 18                  41.3800                 NaN
# 19                  41.3800                 NaN
# 20                  41.3800                 NaN
# 21                  48.3100                 NaN
# 22                   9.9500                 NaN
# 23                  21.1400                 NaN
# 24                  47.2300                 NaN
# 25                  40.3000               21.85
# 26                  38.3700               27.71
# 27                  38.2000                 NaN
# 28                  40.4600                 NaN
# 29                  35.4950                 NaN
# 30                  38.3700                 NaN
#
#     CEPEconomicallyDisadvantagedRate  Grad Rate  \
# 0                                NaN        NaN
# 1                            100.000  86.692222
# 2                            100.000  20.732500
# 3                            100.000        NaN
# 4                            100.000        NaN
# 5                            100.000  44.345714
# 6                              1.600  21.747778
# 7                             92.430  97.477778
# 8                            100.000  45.828750
# 9                              1.050  85.250000
# 10                           100.000  36.064444
# 11                           100.000  15.252500
# 12                             0.000  40.100000
# 13                            61.885        NaN
# 14                            92.430        NaN
# 15                           100.000  83.617778
# 16                           100.000        NaN
# 17                           100.000        NaN
# 18                             0.610  36.971111
# 19                             0.610        NaN
# 20                             0.610        NaN
# 21                           100.000  37.110000
# 22                               NaN        NaN
# 23                               NaN        NaN
# 24                               NaN        NaN
# 25                           100.000  56.646667
# 26                           100.000  69.825556
# 27                             0.000  20.357143
# 28                             0.000        NaN
# 29                            60.000        NaN
# 30                            80.000        NaN
#
#     Grad Rate for Economically Disadvantaged Students  \
# 0                                                 NaN
# 1                                           87.472857
# 2                                           24.917500
# 3                                                 NaN
# 4                                                 NaN
# 5                                           40.760000
# 6                                           22.478889
# 7                                           97.155556
# 8                                           40.313333
# 9                                                 NaN
# 10                                          40.905714
# 11                                          15.090000
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                          83.396250
# 16                                                NaN
# 17                                                NaN
# 18                                          33.393333
# 19                                                NaN
# 20                                                NaN
# 21                                          36.426667
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                          57.101111
# 26                                          68.932222
# 27                                          20.561667
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#     Grad Rate for Black/African American Students  Attendance Rate
# 0                                             NaN              NaN
# 1                                       87.490000        81.170000
# 2                                       23.331429              NaN
# 3                                             NaN              NaN
# 4                                             NaN              NaN
# 5                                       48.415000              NaN
# 6                                       21.942500              NaN
# 7                                       98.055556        95.930000
# 8                                       43.672000        77.306667
# 9                                       85.650000        83.320000
# 10                                      40.568571              NaN
# 11                                      14.327500              NaN
# 12                                      38.162500              NaN
# 13                                            NaN              NaN
# 14                                            NaN              NaN
# 15                                      86.307778        80.486667
# 16                                            NaN              NaN
# 17                                            NaN              NaN
# 18                                      37.277500              NaN
# 19                                            NaN              NaN
# 20                                            NaN              NaN
# 21                                      38.794444              NaN
# 22                                            NaN              NaN
# 23                                            NaN              NaN
# 24                                            NaN              NaN
# 25                                      59.858889        78.163333
# 26                                      73.937778        82.950000
# 27                                      26.320000              NaN
# 28                                            NaN              NaN
# 29                                            NaN              NaN
# 30                                            NaN              NaN

# %%
for zips in final_zips:
    temp_df = new_df.loc[new_df['Zip Code'] == zips]
    
    avg_row_index = new_df.index.get_loc(new_df[(new_df['Zip Code'] == zips) & (new_df['SchoolName'] == 'Average')].index[0])
    med_row_index = new_df.index.get_loc(new_df[(new_df['Zip Code'] == zips) & (new_df['SchoolName'] == 'Median')].index[0])
    
    new_df.at[avg_row_index, 'Grad Rate'] = temp_df['Grad Rate'].mean()
    new_df.at[avg_row_index, 'Grad Rate for Economically Disadvantaged Students'] = temp_df['Grad Rate for Economically Disadvantaged Students'].mean()
    new_df.at[avg_row_index, 'Grad Rate for Black/African American Students'] = temp_df['Grad Rate for Black/African American Students'].mean()
    new_df.at[avg_row_index, 'Attendance Rate'] = temp_df['Attendance Rate'].mean()
    
    new_df.at[med_row_index, 'Grad Rate'] = temp_df['Grad Rate'].median()
    new_df.at[med_row_index, 'Grad Rate for Economically Disadvantaged Students'] = temp_df['Grad Rate for Economically Disadvantaged Students'].median()
    new_df.at[med_row_index, 'Grad Rate for Black/African American Students'] = temp_df['Grad Rate for Black/African American Students'].median()
    new_df.at[med_row_index, 'Attendance Rate'] = temp_df['Attendance Rate'].median()
    
display(new_df)
# Out:
# /home/jupyter-user-3/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
#          Sector  Zip Code ulcscode  \
# 0       Charter     19132     3441
# 1      District     19132     4060
# 2   Alternative     19132     8450
# 3           N/A     19132      N/A
# 4           N/A     19132      N/A
# 5   Alternative     19121     2310
# 6   Alternative     19121     3510
# 7      District     19121     4030
# 8      District     19121     4140
# 9      District     19121     5180
# 10  Alternative     19121     8080
# 11  Alternative     19121     8860
# 12  Alternative     19121     8870
# 13          N/A     19121      N/A
# 14          N/A     19121      N/A
# 15     District     19134     5060
# 16          N/A     19134      N/A
# 17          N/A     19134      N/A
# 18  Alternative     19133     8190
# 19          N/A     19133      N/A
# 20          N/A     19133      N/A
# 21  Alternative     19124     3290
# 22      Charter     19124     3301
# 23      Charter     19124     3332
# 24      Charter     19124     3364
# 25     District     19124     7010
# 26     District     19124     7120
# 27  Alternative     19124     8890
# 28  Alternative     19124     8891
# 29          N/A     19124      N/A
# 30          N/A     19124      N/A
#
#                                            SchoolName  StudentEnrollment  \
# 0                          TECH Freire Charter School         494.000000
# 1    Murrell Dobbins Career and Technical High School         774.000000
# 2                                           YESPhilly         126.000000
# 3                                             Average         464.666667
# 4                                              Median         479.333333
# 5                                     Achieve Academy          50.000000
# 6              El Centro de Estudiantes (Big Picture)         100.000000
# 7              High School of Engineering and Science         843.000000
# 8                      Strawberry Mansion High School         249.000000
# 9                     Vaux High School: A Big Picture         305.000000
# 10                                Excel Academy North         208.000000
# 11                             One Bright Ray Mansion         105.000000
# 12                     One Bright Ray Mansion Evening          79.000000
# 13                                            Average         242.375000
# 14                                             Median         208.000000
# 15  Jules E. Mastbaum Area Vocational Technical Hi...         591.000000
# 16                                            Average         591.000000
# 17                                             Median         591.000000
# 18                   One Bright Ray - Fairhill Campus         261.000000
# 19                                            Average         261.000000
# 20                                             Median         261.000000
# 21                                Excel Academy South         207.000000
# 22   Community Academy of Philadelphia Charter School        1246.000000
# 23            Mariana Bracetti Academy Charter School        1509.000000
# 24      First Philadelphia Preparatory Charter School        1857.000000
# 25                              Frankford High School         861.000000
# 26                            Samuel Fels High School        1238.000000
# 27                    One Bright Ray - Simpson Campus         267.000000
# 28                   One Bright Ray Simpson - Evening         131.000000
# 29                                            Average         914.500000
# 30                                             Median         914.500000
#
#     BlackAfricanAmericanPCT  Matriculation Rate  \
# 0                   93.5200                 NaN
# 1                   89.4100               25.95
# 2                   91.2700                 NaN
# 3                   91.4000                 NaN
# 4                   91.3350                 NaN
# 5                   92.0000                 NaN
# 6                   52.0000                 NaN
# 7                   58.9600               78.79
# 8                   92.3700                0.00
# 9                   89.5100               36.17
# 10                  91.8300                 NaN
# 11                  87.6200                 NaN
# 12                  88.6100                 NaN
# 13                  81.6125                 NaN
# 14                  88.6100                 NaN
# 15                  43.1500               20.25
# 16                  43.1500                 NaN
# 17                  43.1500                 NaN
# 18                  41.3800                 NaN
# 19                  41.3800                 NaN
# 20                  41.3800                 NaN
# 21                  48.3100                 NaN
# 22                   9.9500                 NaN
# 23                  21.1400                 NaN
# 24                  47.2300                 NaN
# 25                  40.3000               21.85
# 26                  38.3700               27.71
# 27                  38.2000                 NaN
# 28                  40.4600                 NaN
# 29                  35.4950                 NaN
# 30                  38.3700                 NaN
#
#     CEPEconomicallyDisadvantagedRate  Grad Rate  \
# 0                                NaN        NaN
# 1                            100.000  86.692222
# 2                            100.000  20.732500
# 3                            100.000  53.712361
# 4                            100.000  53.712361
# 5                            100.000  44.345714
# 6                              1.600  21.747778
# 7                             92.430  97.477778
# 8                            100.000  45.828750
# 9                              1.050  85.250000
# 10                           100.000  36.064444
# 11                           100.000  15.252500
# 12                             0.000  40.100000
# 13                            61.885  48.258371
# 14                            92.430  42.222857
# 15                           100.000  83.617778
# 16                           100.000  83.617778
# 17                           100.000  83.617778
# 18                             0.610  36.971111
# 19                             0.610  36.971111
# 20                             0.610  36.971111
# 21                           100.000  37.110000
# 22                               NaN        NaN
# 23                               NaN        NaN
# 24                               NaN        NaN
# 25                           100.000  56.646667
# 26                           100.000  69.825556
# 27                             0.000  20.357143
# 28                             0.000        NaN
# 29                            60.000  45.984841
# 30                            80.000  46.878333
#
#     Grad Rate for Economically Disadvantaged Students  \
# 0                                                 NaN
# 1                                           87.472857
# 2                                           24.917500
# 3                                           56.195179
# 4                                           56.195179
# 5                                           40.760000
# 6                                           22.478889
# 7                                           97.155556
# 8                                           40.313333
# 9                                                 NaN
# 10                                          40.905714
# 11                                          15.090000
# 12                                                NaN
# 13                                          42.783915
# 14                                          40.536667
# 15                                          83.396250
# 16                                          83.396250
# 17                                          83.396250
# 18                                          33.393333
# 19                                          33.393333
# 20                                          33.393333
# 21                                          36.426667
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                          57.101111
# 26                                          68.932222
# 27                                          20.561667
# 28                                                NaN
# 29                                          45.755417
# 30                                          46.763889
#
#     Grad Rate for Black/African American Students  Attendance Rate
# 0                                             NaN              NaN
# 1                                       87.490000        81.170000
# 2                                       23.331429              NaN
# 3                                       55.410714        81.170000
# 4                                       55.410714        81.170000
# 5                                       48.415000              NaN
# 6                                       21.942500              NaN
# 7                                       98.055556        95.930000
# 8                                       43.672000        77.306667
# 9                                       85.650000        83.320000
# 10                                      40.568571              NaN
# 11                                      14.327500              NaN
# 12                                      38.162500              NaN
# 13                                      48.849203        85.518889
# 14                                      42.120286        83.320000
# 15                                      86.307778        80.486667
# 16                                      86.307778        80.486667
# 17                                      86.307778        80.486667
# 18                                      37.277500              NaN
# 19                                      37.277500              NaN
# 20                                      37.277500              NaN
# 21                                      38.794444              NaN
# 22                                            NaN              NaN
# 23                                            NaN              NaN
# 24                                            NaN              NaN
# 25                                      59.858889        78.163333
# 26                                      73.937778        82.950000
# 27                                      26.320000              NaN
# 28                                            NaN              NaN
# 29                                      49.727778        80.556667
# 30                                      49.326667        80.556667
