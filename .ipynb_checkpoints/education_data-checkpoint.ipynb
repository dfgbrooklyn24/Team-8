# %%
import pandas as pd

schools_data = pd.read_csv('shared_data_read_only/Education-Data/2023-2024 Master School List (20231003).csv')
schools_data.head()
# Out:
#    PA Code NSC Code     NCES Code     AUN Code  ULCS Code SRC School ID  \
# 0   3847.0   393345  4.218990e+11  126515001.0       1010           101
# 1   3860.0   393555  4.218990e+11  126515001.0       1020           102
# 2   7903.0   392779  4.218990e+11  126515001.0       1030           103
# 3   7780.0   393347  4.218990e+11  126515001.0       1050           105
# 4   7245.0   393944  4.218990e+11  126515001.0       1100           110
#
#               School Name (ULCS)                             Publication Name  \
# 0       JOHN BARTRAM HIGH SCHOOL                     John Bartram High School
# 1  WEST PHILADELPHIA HIGH SCHOOL                West Philadelphia High School
# 2      HIGH SCHOOL OF THE FUTURE                    High School of the Future
# 3       PAUL ROBESON HIGH SCHOOL  Paul Robeson High School for Human Services
# 4              SAYRE HIGH SCHOOL                 William L. Sayre High School
#
# ...

# %%
zip_19121 = [19121]
zip_19121_df = schools_data.loc[schools_data['Zip Code'].isin(zip_19121)]
zip_19121_df = zip_19121_df.loc[zip_19121_df['Grade 9'] == 1]
zip_19121_df
# Out:
#      PA Code NSC Code     NCES Code     AUN Code  ULCS Code SRC School ID  \
# 39       NaN   393414           NaN  126515001.0       2310           231
# 152      NaN   393211           NaN  126515001.0       3510           351
# 158   7023.0   393342  4.218990e+11  126515001.0       4030           403
# 160   7255.0   393531  4.218990e+11  126515001.0       4140           414
# 188   8440.0   A23513  4.218990e+11  126515001.0       5180           518
# 289      NaN   393249           NaN  126515001.0       8080           808
# 324      NaN   390081           NaN  126515001.0       8860           886
# 325      NaN   A26193           NaN  126515001.0       8870           887
#
#                  School Name (ULCS)                        Publication Name  \
# 39                  ACHIEVE ACADEMY                         Achieve Academy
# 152        EL CENTRO DE ESTUDIANTES  El Centro de Estudiantes (Big Picture)
# ...

# %%
zip_19121_schools = zip_19121_df['ULCS Code'].to_numpy()

enroll_data_19121 = pd.read_csv('shared_data_read_only/Education-Data/2023-2024 Enrollment & Demographics.csv')
enroll_data_19121.head()
# Out:
#   SchoolYear    Sector SubSector  ulcscode                SchoolName  \
# 0  2023-2024  District  District      1010  John Bartram High School
# 1  2023-2024  District  District      1010  John Bartram High School
# 2  2023-2024  District  District      1010  John Bartram High School
# 3  2023-2024  District  District      1010  John Bartram High School
# 4  2023-2024  District  District      1010  John Bartram High School
#
#   LearningNetwork  GradeLevel  StudentEnrollment  ELCount  ELPCT  ...  \
# 0      Network 13          09                158     24.0  15.19  ...
# 1      Network 13          10                145     40.0  27.59  ...
# 2      Network 13          11                111     23.0  20.72  ...
# 3      Network 13          12                112     27.0  24.11  ...
# 4      Network 13  All Grades                526    114.0  21.67  ...
#
#    BlackAfricanAmericanPCT  HispanicCount  HispanicPCT  MultiRaceCount  \
# ...

# %%
enroll_data_19121 = enroll_data_19121.loc[enroll_data_19121['ulcscode'].isin(zip_19121_schools)]
enroll_data_19121 = enroll_data_19121.loc[enroll_data_19121['GradeLevel'].str.contains('All Grades')]
enroll_data_19121
# Out:
#      SchoolYear       Sector       SubSector  ulcscode  \
# 311   2023-2024  Alternative  Alt Contracted      2310
# 1323  2023-2024  Alternative  Alt Contracted      3510
# 1355  2023-2024     District        District      4030
# 1365  2023-2024     District        District      4140
# 1603  2023-2024     District        District      5180
# 2351  2023-2024  Alternative  Alt Contracted      8080
# 2615  2023-2024  Alternative  Alt Contracted      8860
# 2620  2023-2024  Alternative  Alt Contracted      8870
#
#                                   SchoolName LearningNetwork  GradeLevel  \
# 311                          Achieve Academy     Opportunity  All Grades
# 1323  El Centro de Estudiantes (Big Picture)     Opportunity  All Grades
# 1355  High School of Engineering and Science       Network 1  All Grades
# 1365          Strawberry Mansion High School       Network 4  All Grades
# 1603         Vaux High School: A Big Picture      Innovation  All Grades
# ...

# %%
enroll_data_19121 = enroll_data_19121[["Sector", "SchoolName", "StudentEnrollment", "BlackAfricanAmericanPCT", "CEPEconomicallyDisadvantagedRate"]]

enroll_data_19121.loc[len(enroll_data_19121.index)] = ['N/A', 'Average', enroll_data_19121['StudentEnrollment'].mean(), enroll_data_19121['BlackAfricanAmericanPCT'].mean(), enroll_data_19121['CEPEconomicallyDisadvantagedRate'].mean()]
enroll_data_19121.loc[len(enroll_data_19121.index)] = ['N/A', 'Median', enroll_data_19121['StudentEnrollment'].median(), enroll_data_19121['BlackAfricanAmericanPCT'].median(), enroll_data_19121['CEPEconomicallyDisadvantagedRate'].median()]

enroll_data_19121.round(2)
# Out:
# /tmp/ipykernel_63103/2660524237.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enroll_data_19121.loc[len(enroll_data_19121.index)] = ['N/A', 'Average', enroll_data_19121['StudentEnrollment'].mean(), enroll_data_19121['BlackAfricanAmericanPCT'].mean(), enroll_data_19121['CEPEconomicallyDisadvantagedRate'].mean()]
# /tmp/ipykernel_63103/2660524237.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
zip_19132 = [19132]
zip_19132_df = schools_data.loc[schools_data['Zip Code'].isin(zip_19132)]
zip_19132_df = zip_19132_df.loc[zip_19132_df['Grade 9'] == 1]
zip_19132_df
# Out:
#      PA Code NSC Code     NCES Code     AUN Code  ULCS Code SRC School ID  \
# 147   8359.0   390061  4.200900e+11  126511530.0       3441           X41
# 159   3841.0   393395  4.218990e+11  126515001.0       4060           406
# 316      NaN   393233           NaN  126515001.0       8450           845
#
#               School Name (ULCS)  \
# 147   TECH FREIRE CHARTER SCHOOL
# 159  MURRELL DOBBINS HIGH SCHOOL
# 316                    YESPHILLY
#
#                                      Publication Name  \
# 147                        TECH Freire Charter School
# 159  Murrell Dobbins Career and Technical High School
# 316                                         YESPhilly
#
#                            Publication Name Alpha List Abbreviated Name  ...  \
# 147                         Tech Freire Charter School      TECH Freire  ...
# 159  Dobbins, Murrell Career and Technical Educatio...          Dobbins  ...
# ...
